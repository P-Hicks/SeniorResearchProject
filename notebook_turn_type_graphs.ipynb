# %%
from notebook_utils.queries import run_query, run_query_file

# %%
from notebook_utils.graphs.scatterplots import scatterplot

# %%
from notebook_utils.dataframes import get_stats_df

df = get_stats_df()
statistics = df.groupby(['name']).describe()
statistics
# Out:
#                 numturns                                                      \
#                    count       mean        std  min   25%   50%   75%    max
# name
# NewBiggestFirst  27500.0  13.558436   4.623208  2.0  11.0  13.0  15.0  112.0
# Replacement      27500.0  14.286655  11.819695  2.0  10.0  13.0  15.0  845.0
# Tunnels          27500.0  14.114000   4.410760  2.0  11.0  13.0  16.0   48.0
#
#                 numdiscards            ... percentnones            \
#                       count      mean  ...          75%       max
# name                                   ...
# NewBiggestFirst     27500.0  5.723745  ...     0.000000  0.000000
# Replacement         27500.0  7.177491  ...     0.111111  0.461538
# Tunnels             27500.0  5.498982  ...     0.000000  0.000000
#
#                 avgcomputationaltime                                          \
#                                count          mean          std          min
# name
# ...

# %%
scatterplot(df, 'NewBiggestFirst', xfield='percentdiscards', yfield='numturns', field="discards")

# %%
scatterplot(df, 'NewBiggestFirst', xfield='percentdiscards', yfield='numturns', field="discards", show_size=False)

# %%
scatterplot(df, 'Tunnels', xfield='percentdiscards', yfield='numturns', field="discards")

# %%
scatterplot(df, 'Tunnels', xfield='percentdiscards', yfield='numturns', field="discards", show_size=False)

# %%
scatterplot(df, 'Replacement', xfield='percentdiscards', yfield='numturns', field="discards")

# %%
scatterplot(df, 'Replacement', xfield='percentdiscards', yfield='numturns', field="discards", show_size=False)

# %%
scatterplot(df, 'Replacement', xfield='percentdiscards', yfield='numturns', field="discards", max_turns=100)

# %%
scatterplot(df, 'Replacement', xfield='percentdiscards', yfield='numturns', field="discards", max_turns=100, show_size=False)

# %%
# all
scatterplot(df, None, xfield='percentdiscards', yfield='numturns', field="discards", max_turns=100, show_size=False)

# %%
scatterplot(df, None, xfield='percentdiscards', yfield='numturns', field="discards", max_turns=100, show_size=True)

# %%
scatterplot(df, 'NewBiggestFirst', xfield='percentdraws', yfield='numturns', field="draws")

# %%
scatterplot(df, 'Replacement', xfield='percentdraws', yfield='numturns', field="draws")

# %%
scatterplot(df, 'Tunnels', xfield='percentdraws', yfield='numturns', field="draws")

# %%
scatterplot(df, None, xfield='percentdraws', yfield='numturns', field="draws", max_turns=100)

# %%
scatterplot(df, 'NewBiggestFirst', xfield='percentnones', yfield='numturns', field="nones")

# %%
scatterplot(df, 'Tunnels', xfield='percentnones', yfield='numturns', field="nones")

# %%
scatterplot(df, 'Replacement', xfield='percentnones', yfield='numturns', field="nones")

# %%
scatterplot(df, 'Replacement', xfield='percentnones', yfield='numturns', field="nones", show_size=False)

# %%
scatterplot(df, None, xfield='percentnones', yfield='numturns', field="nones", show_size=True, max_turns=100)
